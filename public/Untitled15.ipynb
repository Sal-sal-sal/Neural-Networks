# %%
import keras
from keras import backend as kbe

# %%
keras.json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-4a4ea818190b> in <cell line: 0>()
# ----> 1 keras.json
#
# AttributeError: module 'keras' has no attribute 'json'
